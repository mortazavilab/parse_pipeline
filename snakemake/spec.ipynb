# %%
import pandas as pd
from snakemake.io import expand
import yaml
import numpy as np
from utils import *
from sm_utils import *
from bc_utils import *

# %%
config_file = '../configs/config.yml'
with open(config_file) as f:
    config = yaml.safe_load(f)

# %%
# variables to change (again these could go in
# a future analysis spec)
# config_tsv = 'configs/test_2.tsv'
# config_tsv = 'configs/test_3.tsv'
# config_tsv = '../configs/test_4.tsv'
config_tsv = '../configs/test_fastqs_for_exp_spec.tsv'
subpool_tsv = '../configs/subpool_metadata.tsv'
sample_csv = '../configs/sample_metadata.csv'
kit = 'WT_mega'
chemistry = 'v2'
first_min_counts = 500

# read in config / analysis spec
df = parse_config(config_tsv)
bc_df = get_bc1_matches(kit, chemistry)
sample_df = parse_sample_df(sample_csv)
subpool_df = pd.read_csv(subpool_tsv, sep='\t')

# %%
import numpy as np
import yaml
from collections import defaultdict
# employee_dict={'employee': {'name': 'John Doe',  'age': 35,
#   'job': {'title': 'Software Engineer','department': 'IT','years_of_experience': 10},
#   'address': {'street': '123 Main St.', 'city': 'San Francisco','state': 'CA', 'zip': 94102}}}
# print("The python dictionary is:")
# print(employee_dict)
# yaml_string=yaml.dump(employee_dict)
# print("The YAML string is:")
# print(yaml_string)

# %%
def make_exp_spec_from_sample_df(sample_df, experiment, ofile):
    """
    Parameters:
        sample_df (pandas DataFrame): Output from parse_sample_df; derived from
            the Google Sheets thingie
        experiment (str): Name of experiment. Will be used to subset the sample_df
        ofile (str): Path to output .yml file
    """
    exp_spec = dict()
    exp_spec['samples'] = dict()
    
    # subset on correct experiment
    sample_df = sample_df.loc[sample_df.plate==experiment].copy(deep=True)
    
    # make sure that we only have one kit / chemistry for this experiment
    assert len(sample_df['Protocol'].unique().tolist()) == 1
    assert len(sample_df['Chemistry'].unique().tolist()) == 1
    
    # kit + chemistry
    exp_spec['protocol'] = sample_df['Protocol'].tolist()[0]
    exp_spec['chemistry'] = sample_df['Chemistry'].tolist()[0]
    
    # list of samples for each row / col well
    def make_alias_list(x, alias_cols):
        """
        Turn the alias sample columns into a list that's one column
        """
        aliases = [a for a in x[alias_cols] if not str(a)=='nan']
        return aliases    

    alias_cols = ['alias_tissue1', 'alias_tissue2', 'alias_tissue3', 'alias_tissue4']
    sample_df['well_row'] = sample_df.bc1_well.str.slice(0,1)
    sample_df['well_col'] = sample_df.bc1_well.str.slice(1).astype(int)
    sample_df = sample_df[alias_cols+['well_row', 'well_col']]
    sample_df['samples'] = sample_df.apply(lambda x: make_alias_list(x, alias_cols), axis=1)
    sample_df.drop(alias_cols, axis=1, inplace=True)

    for row in sample_df.well_row.unique().tolist():
        temp = sample_df.loc[sample_df.well_row==row].copy(deep=True)
        for ind, entry in temp.iterrows():
            if row not in exp_spec['samples'].keys():
                exp_spec['samples'][row] = dict()
            exp_spec['samples'][row][entry.well_col] = entry['samples']

    yml_str = yaml.dump(exp_spec)
    with open(ofile, 'w') as o:
        o.write(yml_str)

# %%
# this works for the samples and exp overview
sample_df = parse_sample_df(sample_csv)
# make_exp_spec_from_sample_df(sample_df, 'igvf_010', 'igvf_010_exp_spec.yml')

# %%
sample_df.head()
# Out:
#   Mouse_Tissue_ID                             alias_tissue1  \
# 0  016_B6J_10F_03  ali-mortazavi:016_B6J_10F_03_NTR_0000646
# 1  017_B6J_10M_03  ali-mortazavi:017_B6J_10M_03_NTR_0000646
# 2  018_B6J_10F_03  ali-mortazavi:018_B6J_10F_03_NTR_0000646
# 3  019_B6J_10M_03  ali-mortazavi:019_B6J_10M_03_NTR_0000646
# 4  020_B6J_10F_03  ali-mortazavi:020_B6J_10F_03_NTR_0000646
#
#                               alias_tissue2 alias_tissue3 alias_tissue4  \
# 0  ali-mortazavi:016_B6J_10F_03_NTR_0000750           NaN           NaN
# 1  ali-mortazavi:017_B6J_10M_03_NTR_0000750           NaN           NaN
# 2  ali-mortazavi:018_B6J_10F_03_NTR_0000750           NaN           NaN
# 3  ali-mortazavi:019_B6J_10M_03_NTR_0000750           NaN           NaN
# 4  ali-mortazavi:020_B6J_10F_03_NTR_0000750           NaN           NaN
#
#       plate       Protocol Chemistry bc1_well well_type  ... Age_weeks  \
# 0  igvf_003  Parse_WT_Mega        v2       A1    Single  ...        10
# 1  igvf_003  Parse_WT_Mega        v2       A2    Single  ...        10
# 2  igvf_003  Parse_WT_Mega        v2       A3    Single  ...        10
# 3  igvf_003  Parse_WT_Mega        v2       A4    Single  ...        10
# 4  igvf_003  Parse_WT_Mega        v2       A5    Single  ...        10
#
#    Age_days Body_weight_g Estrus_cycle Dissection_date Dissection_time  \
# 0      72.0          21.1     Diestrus        10/27/22         9:01 AM
# 1      72.0          26.3          NaN        10/27/22        11:44 AM
# 2      72.0          21.0    Proestrus        10/27/22         9:38 AM
# 3      72.0          29.0          NaN        10/27/22        12:12 PM
# 4      72.0          18.5     Diestrus        10/27/22        10:14 AM
#
#   Tissue_weight_mg  mult_genotype_1 mult_genotype_2 mult_genotype
# 0            141.0              NaN             NaN           NaN
# 1            141.0              NaN             NaN           NaN
# 2            143.0              NaN             NaN           NaN
# 3            141.0              NaN             NaN           NaN
# 4            149.0              NaN             NaN           NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ## the subpools >_<

# %%
df = df.merge(subpool_df, how='left', on=['subpool', 'plate'])

# %%
# add some extra columns
plat_dict = {'prom': 'ONT PromethION',
             'grid': 'ONT GridION',
             'nova': 'Illumina NovaSeq',
             'next': 'Illumina NextSeq'}
plat_to_seq_type_dict = {'prom': 'long',
                         'grid': 'long',
                         'nova': 'short',
                         'next': 'short'}
df['long_or_short'] = df.platform.map(plat_to_seq_type_dict)
df['platform_hr'] = df.platform.map(plat_dict)

# get thing
gb_cols = ['subpool', 'long_or_short', 'platform', 'run']
gb_fastq_cols = gb_cols+['fastq']
temp = df[gb_fastq_cols].groupby(gb_cols)['fastq'].apply(list)
temp.to_dict()
# Out:
# {('Sublibrary_2',
#   'long',
#   'grid',
#   1): ['/dfs7/samlab/seyedam/IGVF/igvf_010/grid/igvf_010_lig-blk.fastq.gz'],
#  ('Sublibrary_2',
#   'long',
#   'prom',
#   1): ['/dfs7/samlab/seyedam/IGVF/igvf_010/prom/igvf_010_lig-blk.fastq.gz'],
#  ('Sublibrary_2',
#   'short',
#   'next',
#   1): ['/dfs7/samlab/seyedam/IGVF/igvf_010/next1/Sublibrary_3_S2_L004_R1_001.fastq.gz'],
#  ('Sublibrary_2',
#   'short',
#   'next',
#   2): ['/dfs7/samlab/seyedam/IGVF/igvf_010/next2/Sublibrary_3_S2_L004_R1_001.fastq.gz'],
#  ('Sublibrary_2',
#   'short',
#   'nova',
#   1): ['/dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Sublibrary_2_S1_L001_R1_001.fastq.gz', '/dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Sublibrary_2_S1_L002_R1_001.fastq.gz', '/dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Sublibrary_2_S1_L003_R1_001.fastq.gz', '/dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Sublibrary_2_S1_L004_R1_001.fastq.gz'],
#  ('Sublibrary_2',
#   'short',
#   'nova',
#   2): ['/dfs7/samlab/seyedam/IGVF/igvf_010/nova2/Sublibrary_2_S1_L001_R1_001.fastq.gz', '/dfs7/samlab/seyedam/IGVF/igvf_010/nova2/Sublibrary_2_S1_L002_R1_001.fastq.gz', '/dfs7/samlab/seyedam/IGVF/igvf_010/nova2/Sublibrary_2_S1_L003_R1_001.fastq.gz', '/dfs7/samlab/seyedam/IGVF/igvf_010/nova2/Sublibrary_2_S1_L004_R1_001.fastq.gz'],
#  ('Sublibrary_3',
#   'short',
#   'nova',
#   1): ['/dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Sublibrary_3_S2_L001_R1_001.fastq.gz', '/dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Sublibrary_3_S2_L002_R1_001.fastq.gz', '/dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Sublibrary_3_S2_L003_R1_001.fastq.gz', '/dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Sublibrary_3_S2_L004_R1_001.fastq.gz'],
#  ('Sublibrary_3',
#   'short',
#   'nova',
#   2): ['/dfs7/samlab/seyedam/IGVF/igvf_010/nova2/Sublibrary_3_S2_L001_R1_001.fastq.gz', '/dfs7/samlab/seyedam/IGVF/igvf_010/nova2/Sublibrary_3_S2_L002_R1_001.fastq.gz', '/dfs7/samlab/seyedam/IGVF/igvf_010/nova2/Sublibrary_3_S2_L003_R1_001.fastq.gz', '/dfs7/samlab/seyedam/IGVF/igvf_010/nova2/Sublibrary_3_S2_L004_R1_001.fastq.gz']}

# %%
exp_spec = {}
exp_spec['subpools'] = {}
subpool_cols = ['subpool', 'Count', 'i7_subpool_barcode', 'i5_subpool_barcode', 'Selection']
temp = df[subpool_cols].drop_duplicates().copy(deep=True)
temp.head()
for ind, entry in temp.iterrows():
    subpool = entry.subpool
    if c not in exp_spec['subpools'].keys():
            exp_spec['subpools'][subpool] = {}
    for c in subpool_cols:
        exp_spec['subpools'][subpool][c] = entry[c]

# %%
exp_spec
# Out:
# {'subpools': {'Sublibrary_2': {'subpool': 'Sublibrary_2',
#    'Count': 67000,
#    'i7_subpool_barcode': 'ACTTGA',
#    'i5_subpool_barcode': nan,
#    'Selection': 'EX'},
#   'Sublibrary_3': {'subpool': 'Sublibrary_3',
#    'Count': 67000,
#    'i7_subpool_barcode': 'GATCAG',
#    'i5_subpool_barcode': nan,
#    'Selection': 'NO'}}}

# %%
subpool_cols = ['subpool', 'Count', 'i7_subpool_barcode', 'i5_subpool_barcode', 'Selection']
df[subpool_cols+['fastq']].groupby(subpool_cols, dropna=False).count().to_dict(orient='index')
# Out:
# {('Sublibrary_2', 67000, 'ACTTGA', nan, 'EX'): {'fastq': 8},
#  ('Sublibrary_3', 67000, 'GATCAG', nan, 'NO'): {'fastq': 8}}

# %%
df = df.merge(subpool_df, how='left', on=['subpool', 'plate'])

# %%
df = pd.DataFrame([
           ['A', 'a', 123, 1], 
           ['B', 'b', 345, 5], 
           ['C', 'c', 712, 4],
           ['B', 'b', 768, 2], 
           ['B', 'b', 768, 3], 
           ['A', 'a', 123, 9], 
           ['C', 'c', 178, 6], 
           ['C', 'c', 178, 5],  
           ['A', 'a', 321, 3]])
df.columns = ['subpool', 'Count', 'sequencing', 'fastq']
df['i7_subpool_barcode'] = df['subpool']
df['i5_subpool_barcode'] = df['subpool']
df['Selection'] = 'EX'
df.head()
# Out:
#   subpool Count  sequencing  fastq i7_subpool_barcode i5_subpool_barcode  \
# 0       A     a         123      1                  A                  A
# 1       B     b         345      5                  B                  B
# 2       C     c         712      4                  C                  C
# 3       B     b         768      2                  B                  B
# 4       B     b         768      3                  B                  B
#
#   Selection
# 0        EX
# 1        EX
# 2        EX
# 3        EX
# 4        EX

# %%
# subpool_cols = ['subpool', 'Count', 'i7_subpool_barcode', 'i5_subpool_barcode', 'Selection']


# # d = {'subpools': {k[0]: \
# #         dict(dict([(subpool_cols[i],k[i]) for i in range(1, len(subpool_cols))]).update(\
# #          **('Sequencing':f.groupby('sequencing')['fastq'].apply(list).to_dict())) \
# #      for k, f in df.groupby(subpool_cols)}}

# # # d = {'subpools': {k[0]: \
# # #         dict([(subpool_cols[i],k[i]) for i in range(1, len(subpool_cols))]) \
# # #      for k, f in df.groupby(subpool_cols)}}

# # # d = {'subpools': {k[0]: \
# # #         {subpool_cols[1]: k[1], 'Sequencing': f.groupby('sequencing')['fastq'].apply(list).to_dict()}
# # #      for k, f in df.groupby(subpool_cols)}}

# %%
# d

# %%
# df.head()
# subpool_cols = ['subpool', 'Count']
# df.columns = ['subpool', 'Count', 'sequencing', 'fastq']
# d = {'subpools': {k[0]: {'Count': k[1]}}
#      for k, f in df.groupby(subpool_cols)}

# %%
df.head()
df['level'] = 'subpools'

# %%
temp = df[['level', 'subpool', 'Count', 'Selection', 'i7_subpool_barcode', 'i5_subpool_barcode']].drop_duplicates()
data = temp.groupby('level').apply(
            lambda x: x.set_index('subpool').to_dict(orient='index')).to_dict()
data
# Out:
# {'subpools': {'Sublibrary_2': {'level': 'subpools',
#    'Count': 67000,
#    'Selection': 'EX',
#    'i7_subpool_barcode': 'ACTTGA',
#    'i5_subpool_barcode': nan},
#   'Sublibrary_3': {'level': 'subpools',
#    'Count': 67000,
#    'Selection': 'NO',
#    'i7_subpool_barcode': 'GATCAG',
#    'i5_subpool_barcode': nan}}}

# %%
# temp = df.copy(deep=True)
# temp.groupby('level').groupby(['subpool', 'Count', 'Selection', 'i7_subpool_barcode', 'i5_subpool_barcode'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-bb2b6dec09e8> in <module>
#       1 temp = df.copy(deep=True)
# ----> 2 temp.groupby('level').groupby(['subpool', 'Count', 'Selection', 'i7_subpool_barcode', 'i5_subpool_barcode'])
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     910
#     911         raise AttributeError(
# --> 912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#     914
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
df.head()
plat_to_long_or_short = {'nova': 'short', 'next': 'short',
                         'grid': 'long', 'prom': 'long'}
df['long_or_short'] = df.platform.map(plat_to_long_or_short)
df.head()
# Out:
#                                                fastq       subpool sample  \
# 0  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  Sublibrary_2     S1
# 1  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  Sublibrary_2     S1
# 2  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  Sublibrary_2     S1
# 3  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  Sublibrary_2     S1
# 4  /dfs7/samlab/seyedam/IGVF/igvf_010/nova2/Subli...  Sublibrary_2     S1
#
#       plate  lane  run platform                                 path  \
# 0  igvf_010  L001    1     nova  /dfs7/samlab/seyedam/IGVF/igvf_010/
# 1  igvf_010  L002    1     nova  /dfs7/samlab/seyedam/IGVF/igvf_010/
# 2  igvf_010  L003    1     nova  /dfs7/samlab/seyedam/IGVF/igvf_010/
# 3  igvf_010  L004    1     nova  /dfs7/samlab/seyedam/IGVF/igvf_010/
# 4  igvf_010  L001    2     nova  /dfs7/samlab/seyedam/IGVF/igvf_010/
#
#                                        path2  \
# 0  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/
# 1  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/
# 2  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/
# 3  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/
# 4  /dfs7/samlab/seyedam/IGVF/igvf_010/nova2/
#
#                                             r2_fastq  Count Selection  \
# 0  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  67000        EX
# 1  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  67000        EX
# 2  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  67000        EX
# 3  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  67000        EX
# 4  /dfs7/samlab/seyedam/IGVF/igvf_010/nova2/Subli...  67000        EX
#
#    Sublibrary Index i7_subpool_barcode  i5_subpool_barcode     level  \
# 0                 2             ACTTGA                 NaN  subpools
# 1                 2             ACTTGA                 NaN  subpools
# 2                 2             ACTTGA                 NaN  subpools
# 3                 2             ACTTGA                 NaN  subpools
# 4                 2             ACTTGA                 NaN  subpools
#
#   long_or_short
# 0         short
# 1         short
# 2         short
# 3         short
# 4         short

# %%
# go from inside out
temp = df[['fastq', 'r2_fastq', 'run', 'platform']]
d = {k: f.groupby(['run', 'platform'])[['fastq', 'r2_fastq']].apply(list).to_dict()
     for k, f in df.groupby('run')}
d
# Out:
# {1: {(1, 'nova'): ['fastq', 'r2_fastq']},
#  2: {(2, 'nova'): ['fastq', 'r2_fastq']}}

# %%
subpool_cols = ['subpool', 'Count', 'Selection', 'i7_subpool_barcode', 'i5_subpool_barcode']
sequencing_cols = ['long_or_short']
d = {k: f.groupby(sequencing_cols)[].apply(list).to_dict()
     for k, f in df.groupby('subpool_cols')}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-156-da2654014a41> in <module>
#       2 sequencing_cols = ['long_or_short']
#       3 d = {k: f.groupby(sequencing_cols).apply(list).to_dict()
# ----> 4      for k, f in df.groupby('subpool_cols')}
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7639             squeeze=squeeze,  # type: ignore[arg-type]
#    7640             observed=observed,
# -> 7641             dropna=dropna,
#    7642         )
#    7643
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     895                 observed=observed,
#     896                 mutated=self.mutated,
# --> 897                 dropna=self.dropna,
#     898             )
#     899
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     860                 in_axis, level, gpr = False, gpr, None
#     861             else:
# --> 862                 raise KeyError(gpr)
#     863         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     864             # Add key to exclusions
#
# KeyError: 'subpool_cols'

# %%
exp_spec = dict()

# add first level of subpool information
exp_spec['subpools'] = dict()
for s in df.subpool.unique().tolist():
    temp = df.loc[df.subpool==s].copy(deep=True)
    
    # count, i7, i5 barcodes, selection method
    if s not in exp_spec['subpools'].keys():
        exp_spec['subpools'][s] = dict()
    cols = ['Count', 'Selection', 'i7_subpool_barcode',
        'i5_subpool_barcode']
    for c in cols:
        assert len(temp[c].unique().tolist())==1
        exp_spec['subpools'][s][c] = temp[c].values[0]

# %%
# add in the fastqs
short_platforms = ['nova', 'next']
long_platforms = ['grid', 'prom']
exp_spec
for ind, entry in df.iterrows():
    if entry.platform.isin(short_platforms):
        if
# Out:
# {'subpools': {'Sublibrary_2': {'Count': 67000,
#    'Selection': 'EX',
#    'i7_subpool_barcode': 'ACTTGA',
#    'i5_subpool_barcode': nan,
#    'long_read': 'YES'},
#   'Sublibrary_3': {'Count': 67000,
#    'Selection': 'NO',
#    'i7_subpool_barcode': 'GATCAG',
#    'i5_subpool_barcode': nan,
#    'long_read': 'NO'}}}

# %%
subpool_df.head()
# Out:
#       plate       subpool  Count Selection  Sublibrary Index  \
# 0  igvf_010  Sublibrary_2  67000        NO                 2
# 1  igvf_010  Sublibrary_3  67000        NO                 3
# 2  igvf_010  Sublibrary_4  67000        NO                 4
# 3  igvf_010  Sublibrary_5  67000        NO                 5
# 4  igvf_010  Sublibrary_6  67000        NO                 6
#
#   i7_subpool_barcode  i5_subpool_barcode
# 0             ACTTGA                 NaN
# 1             GATCAG                 NaN
# 2             TAGCTT                 NaN
# 3             ATGTCA                 NaN
# 4             CTTGTA                 NaN

# %%
# exp_spec
# Out:
# defaultdict(dict,
#             {'samples': defaultdict(None,
#                          {'A': {'1': ['ali-mortazavi:016_B6J_10F_09_UBERON_0002113'],
#                            '2': ['ali-mortazavi:017_B6J_10M_09_UBERON_0002113'],
#                            '3': ['ali-mortazavi:018_B6J_10F_09_UBERON_0002113'],
#                            '4': ['ali-mortazavi:019_B6J_10M_09_UBERON_0002113'],
#                            '5': ['ali-mortazavi:020_B6J_10F_09_UBERON_0002113'],
#                            '6': ['ali-mortazavi:021_B6J_10M_09_UBERON_0002113'],
#                            '7': ['ali-mortazavi:024_B6J_10F_09_UBERON_0002113'],
#                            '8': ['ali-mortazavi:025_B6J_10M_09_UBERON_0002113'],
#                            '10': ['ali-mortazavi:017_B6J_10M_16_UBERON_0001388',
#                             'ali-mortazavi:067_NODJ_10M_16_UBERON_0001388'],
#                            '11': ['ali-mortazavi:018_B6J_10F_16_UBERON_0001388',
#                             'ali-mortazavi:074_NODJ_10F_16_UBERON_0001388'],
#                            '12': ['ali-mortazavi:019_B6J_10M_16_UBERON_0001388',
#                             'ali-mortazavi:069_NODJ_10M_16_UBERON_0001388'],
#                            '9': ['ali-mortazavi:016_B6J_10F_16_UBERON_0001388',
#                             'ali-mortazavi:066_NODJ_10F_16_UBERON_0001388']},
#                           'B': {'1': ['ali-mortazavi:066_NODJ_10F_09_UBERON_0002113'],
#                            '2': ['ali-mortazavi:067_NODJ_10M_09_UBERON_0002113'],
#                            '3': ['ali-mortazavi:068_NODJ_10F_09_UBERON_0002113'],
#                            '4': ['ali-mortazavi:069_NODJ_10M_09_UBERON_0002113'],
#                            '5': ['ali-mortazavi:070_NODJ_10F_09_UBERON_0002113'],
#                            '6': ['ali-mortazavi:071_NODJ_10M_09_UBERON_0002113'],
#                            '7': ['ali-mortazavi:072_NODJ_10F_09_UBERON_0002113'],
#                            '8': ['ali-mortazavi:073_NODJ_10M_09_UBERON_0002113'],
#                            '10': ['ali-mortazavi:021_B6J_10M_16_UBERON_0001388',
#                             'ali-mortazavi:071_NODJ_10M_16_UBERON_0001388'],
#                            '11': ['ali-mortazavi:024_B6J_10F_16_UBERON_0001388',
#                             'ali-mortazavi:072_NODJ_10F_16_UBERON_0001388'],
#                            '12': ['ali-mortazavi:025_B6J_10M_16_UBERON_0001388',
#                             'ali-mortazavi:073_NODJ_10M_16_UBERON_0001388'],
#                            '9': ['ali-mortazavi:020_B6J_10F_16_UBERON_0001388',
#                             'ali-mortazavi:070_NODJ_10F_16_UBERON_0001388']},
#                           'C': {'1': ['ali-mortazavi:026_AJ_10F_09_UBERON_0002113'],
#                            '2': ['ali-mortazavi:029_AJ_10M_09_UBERON_0002113'],
#                            '3': ['ali-mortazavi:028_AJ_10F_09_UBERON_0002113'],
#                            '4': ['ali-mortazavi:031_AJ_10M_09_UBERON_0002113'],
#                            '5': ['ali-mortazavi:030_AJ_10F_09_UBERON_0002113'],
#                            '6': ['ali-mortazavi:033_AJ_10M_09_UBERON_0002113'],
#                            '7': ['ali-mortazavi:032_AJ_10F_09_UBERON_0002113'],
#                            '8': ['ali-mortazavi:035_AJ_10M_09_UBERON_0002113'],
#                            '10': ['ali-mortazavi:027_AJ_10M_16_UBERON_0001388',
#                             'ali-mortazavi:077_PWKJ_10M_16_UBERON_0001388'],
#                            '11': ['ali-mortazavi:028_AJ_10F_16_UBERON_0001388',
#                             'ali-mortazavi:078_PWKJ_10F_16_UBERON_0001388'],
#                            '12': ['ali-mortazavi:031_AJ_10M_16_UBERON_0001388',
#                             'ali-mortazavi:079_PWKJ_10M_16_UBERON_0001388'],
#                            '9': ['ali-mortazavi:026_AJ_10F_16_UBERON_0001388',
#                             'ali-mortazavi:076_PWKJ_10F_16_UBERON_0001388']},
#                           'D': {'1': ['ali-mortazavi:076_PWKJ_10F_09_UBERON_0002113'],
#                            '2': ['ali-mortazavi:077_PWKJ_10M_09_UBERON_0002113'],
#                            '3': ['ali-mortazavi:078_PWKJ_10F_09_UBERON_0002113'],
#                            '4': ['ali-mortazavi:079_PWKJ_10M_09_UBERON_0002113'],
#                            '5': ['ali-mortazavi:080_PWKJ_10F_09_UBERON_0002113'],
#                            '6': ['ali-mortazavi:081_PWKJ_10M_09_UBERON_0002113'],
#                            '7': ['ali-mortazavi:084_PWKJ_10F_09_UBERON_0002113'],
#                            '8': ['ali-mortazavi:085_PWKJ_10M_09_UBERON_0002113'],
#                            '10': ['ali-mortazavi:033_AJ_10M_16_UBERON_0001388',
#                             'ali-mortazavi:081_PWKJ_10M_16_UBERON_0001388'],
#                            '11': ['ali-mortazavi:034_AJ_10F_16_UBERON_0001388',
#                             'ali-mortazavi:084_PWKJ_10F_16_UBERON_0001388'],
#                            '12': ['ali-mortazavi:035_AJ_10M_16_UBERON_0001388',
#                             'ali-mortazavi:085_PWKJ_10M_16_UBERON_0001388'],
#                            '9': ['ali-mortazavi:030_AJ_10F_16_UBERON_0001388',
#                             'ali-mortazavi:080_PWKJ_10F_16_UBERON_0001388']},
#                           'E': {'1': ['ali-mortazavi:036_129S1J_10F_09_UBERON_0002113'],
#                            '2': ['ali-mortazavi:037_129S1J_10M_09_UBERON_0002113'],
#                            '3': ['ali-mortazavi:038_129S1J_10F_09_UBERON_0002113'],
#                            '4': ['ali-mortazavi:041_129S1J_10M_09_UBERON_0002113'],
#                            '5': ['ali-mortazavi:040_129S1J_10F_09_UBERON_0002113'],
#                            '6': ['ali-mortazavi:043_129S1J_10M_09_UBERON_0002113'],
#                            '7': ['ali-mortazavi:044_129S1J_10F_09_UBERON_0002113'],
#                            '8': ['ali-mortazavi:045_129S1J_10M_09_UBERON_0002113'],
#                            '10': ['ali-mortazavi:037_129S1J_10M_16_UBERON_0001388',
#                             'ali-mortazavi:087_CASTJ_10M_16_UBERON_0001388'],
#                            '11': ['ali-mortazavi:038_129S1J_10F_16_UBERON_0001388',
#                             'ali-mortazavi:092_CASTJ_10F_16_UBERON_0001388'],
#                            '12': ['ali-mortazavi:041_129S1J_10M_16_UBERON_0001388',
#                             'ali-mortazavi:089_CASTJ_10M_16_UBERON_0001388'],
#                            '9': ['ali-mortazavi:042_129S1J_10F_16_UBERON_0001388',
#                             'ali-mortazavi:086_CASTJ_10F_16_UBERON_0001388']},
#                           'F': {'1': ['ali-mortazavi:086_CASTJ_10F_09_UBERON_0002113'],
#                            '2': ['ali-mortazavi:087_CASTJ_10M_09_UBERON_0002113'],
#                            '3': ['ali-mortazavi:088_CASTJ_10F_09_UBERON_0002113'],
#                            '4': ['ali-mortazavi:089_CASTJ_10M_09_UBERON_0002113'],
#                            '5': ['ali-mortazavi:090_CASTJ_10F_09_UBERON_0002113'],
#                            '6': ['ali-mortazavi:091_CASTJ_10M_09_UBERON_0002113'],
#                            '7': ['ali-mortazavi:094_CASTJ_10F_09_UBERON_0002113'],
#                            '8': ['ali-mortazavi:093_CASTJ_10M_09_UBERON_0002113'],
#                            '10': ['ali-mortazavi:043_129S1J_10M_16_UBERON_0001388',
#                             'ali-mortazavi:091_CASTJ_10M_16_UBERON_0001388'],
#                            '11': ['ali-mortazavi:044_129S1J_10F_16_UBERON_0001388',
#                             'ali-mortazavi:094_CASTJ_10F_16_UBERON_0001388'],
#                            '12': ['ali-mortazavi:045_129S1J_10M_16_UBERON_0001388',
#                             'ali-mortazavi:093_CASTJ_10M_16_UBERON_0001388'],
#                            '9': ['ali-mortazavi:040_129S1J_10F_16_UBERON_0001388',
#                             'ali-mortazavi:090_CASTJ_10F_16_UBERON_0001388']},
#                           'G': {'1': ['ali-mortazavi:058_WSBJ_10F_09_UBERON_0002113'],
#                            '2': ['ali-mortazavi:057_WSBJ_10M_09_UBERON_0002113'],
#                            '3': ['ali-mortazavi:060_WSBJ_10F_09_UBERON_0002113'],
#                            '4': ['ali-mortazavi:059_WSBJ_10M_09_UBERON_0002113'],
#                            '5': ['ali-mortazavi:062_WSBJ_10F_09_UBERON_0002113'],
#                            '6': ['ali-mortazavi:061_WSBJ_10M_09_UBERON_0002113'],
#                            '7': ['ali-mortazavi:096_WSBJ_10F_09_UBERON_0002113'],
#                            '8': ['ali-mortazavi:063_WSBJ_10M_09_UBERON_0002113'],
#                            '10': ['ali-mortazavi:057_WSBJ_10M_16_UBERON_0001388',
#                             'ali-mortazavi:047_NZOJ_10M_16_UBERON_0001388'],
#                            '11': ['ali-mortazavi:064_WSBJ_10F_16_UBERON_0001388',
#                             'ali-mortazavi:048_NZOJ_10F_16_UBERON_0001388'],
#                            '12': ['ali-mortazavi:059_WSBJ_10M_16_UBERON_0001388',
#                             'ali-mortazavi:049_NZOJ_10M_16_UBERON_0001388'],
#                            '9': ['ali-mortazavi:058_WSBJ_10F_16_UBERON_0001388',
#                             'ali-mortazavi:046_NZOJ_10F_16_UBERON_0001388']},
#                           'H': {'1': ['ali-mortazavi:046_NZOJ_10F_09_UBERON_0002113'],
#                            '2': ['ali-mortazavi:047_NZOJ_10M_09_UBERON_0002113'],
#                            '3': ['ali-mortazavi:048_NZOJ_10F_09_UBERON_0002113'],
#                            '4': ['ali-mortazavi:049_NZOJ_10M_09_UBERON_0002113'],
#                            '5': ['ali-mortazavi:050_NZOJ_10F_09_UBERON_0002113'],
#                            '6': ['ali-mortazavi:051_NZOJ_10M_09_UBERON_0002113'],
#                            '7': ['ali-mortazavi:052_NZOJ_10F_09_UBERON_0002113'],
#                            '8': ['ali-mortazavi:053_NZOJ_10M_09_UBERON_0002113'],
#                            '10': ['ali-mortazavi:061_WSBJ_10M_16_UBERON_0001388',
#                             'ali-mortazavi:051_NZOJ_10M_16_UBERON_0001388'],
#                            '11': ['ali-mortazavi:096_WSBJ_10F_16_UBERON_0001388',
#                             'ali-mortazavi:052_NZOJ_10F_16_UBERON_0001388'],
#                            '12': ['ali-mortazavi:063_WSBJ_10M_16_UBERON_0001388',
#                             'ali-mortazavi:053_NZOJ_10M_16_UBERON_0001388'],
#                            '9': ['ali-mortazavi:062_WSBJ_10F_16_UBERON_0001388',
#                             'ali-mortazavi:050_NZOJ_10F_16_UBERON_0001388']}}),
#              'protocol': 'Parse_WT_Mega',
#              'chemistry': 'v2'})

# %%
# Out:
#                               alias_tissue1  \
# 0  ali-mortazavi:016_B6J_10F_03_NTR_0000646
# 1  ali-mortazavi:017_B6J_10M_03_NTR_0000646
# 2  ali-mortazavi:018_B6J_10F_03_NTR_0000646
# 3  ali-mortazavi:019_B6J_10M_03_NTR_0000646
# 4  ali-mortazavi:020_B6J_10F_03_NTR_0000646
#
#                               alias_tissue2 alias_tissue3 alias_tissue4  \
# 0  ali-mortazavi:016_B6J_10F_03_NTR_0000750           NaN           NaN
# 1  ali-mortazavi:017_B6J_10M_03_NTR_0000750           NaN           NaN
# 2  ali-mortazavi:018_B6J_10F_03_NTR_0000750           NaN           NaN
# 3  ali-mortazavi:019_B6J_10M_03_NTR_0000750           NaN           NaN
# 4  ali-mortazavi:020_B6J_10F_03_NTR_0000750           NaN           NaN
#
#   well_row well_col                                            samples
# 0        A        1  [ali-mortazavi:016_B6J_10F_03_NTR_0000646, ali...
# 1        A        2  [ali-mortazavi:017_B6J_10M_03_NTR_0000646, ali...
# 2        A        3  [ali-mortazavi:018_B6J_10F_03_NTR_0000646, ali...
# 3        A        4  [ali-mortazavi:019_B6J_10M_03_NTR_0000646, ali...
# 4        A        5  [ali-mortazavi:020_B6J_10F_03_NTR_0000646, ali...

# %%
# Out:
#   well_row well_col                                            samples
# 0        A        1  [ali-mortazavi:016_B6J_10F_03_NTR_0000646, ali...
# 1        A        2  [ali-mortazavi:017_B6J_10M_03_NTR_0000646, ali...
# 2        A        3  [ali-mortazavi:018_B6J_10F_03_NTR_0000646, ali...
# 3        A        4  [ali-mortazavi:019_B6J_10M_03_NTR_0000646, ali...
# 4        A        5  [ali-mortazavi:020_B6J_10F_03_NTR_0000646, ali...

# %%
sample_df['alias_tissue3'].unique()
# Out:
# array([nan, 'ali-mortazavi:017_B6J_10M_01_UBERON_0000007',
#        'ali-mortazavi:018_B6J_10F_01_UBERON_0000007',
#        'ali-mortazavi:019_B6J_10M_01_UBERON_0000007',
#        'ali-mortazavi:016_B6J_10F_01_UBERON_0000007',
#        'ali-mortazavi:021_B6J_10M_01_UBERON_0000007',
#        'ali-mortazavi:024_B6J_10F_01_UBERON_0000007',
#        'ali-mortazavi:025_B6J_10M_01_UBERON_0000007',
#        'ali-mortazavi:020_B6J_10F_01_UBERON_0000007',
#        'ali-mortazavi:029_AJ_10M_01_UBERON_0000007',
#        'ali-mortazavi:028_AJ_10F_01_UBERON_0000007',
#        'ali-mortazavi:031_AJ_10M_01_UBERON_0000007',
#        'ali-mortazavi:026_AJ_10F_01_UBERON_0000007',
#        'ali-mortazavi:033_AJ_10M_01_UBERON_0000007',
#        'ali-mortazavi:032_AJ_10F_01_UBERON_0000007',
#        'ali-mortazavi:035_AJ_10M_01_UBERON_0000007',
#        'ali-mortazavi:030_AJ_10F_01_UBERON_0000007',
#        'ali-mortazavi:037_129S1J_10M_01_UBERON_0000007',
#        'ali-mortazavi:038_129S1J_10F_01_UBERON_0000007',
#        'ali-mortazavi:041_129S1J_10M_01_UBERON_0000007',
#        'ali-mortazavi:036_129S1J_10F_01_UBERON_0000007',
#        'ali-mortazavi:043_129S1J_10M_01_UBERON_0000007',
#        'ali-mortazavi:044_129S1J_10F_01_UBERON_0000007',
#        'ali-mortazavi:045_129S1J_10M_01_UBERON_0000007',
#        'ali-mortazavi:040_129S1J_10F_01_UBERON_0000007',
#        'ali-mortazavi:057_WSBJ_10M_01_UBERON_0000007',
#        'ali-mortazavi:060_WSBJ_10F_01_UBERON_0000007',
#        'ali-mortazavi:059_WSBJ_10M_01_UBERON_0000007',
#        'ali-mortazavi:058_WSBJ_10F_01_UBERON_0000007',
#        'ali-mortazavi:061_WSBJ_10M_01_UBERON_0000007',
#        'ali-mortazavi:096_WSBJ_10F_01_UBERON_0000007',
#        'ali-mortazavi:063_WSBJ_10M_01_UBERON_0000007',
#        'ali-mortazavi:062_WSBJ_10F_01_UBERON_0000007',
#        'ali-mortazavi:018_B6J_10F_26_UBERON_0000993',
#        'ali-mortazavi:020_B6J_10F_26_UBERON_0000993',
#        'ali-mortazavi:024_B6J_10F_26_UBERON_0000993',
#        'ali-mortazavi:016_B6J_10F_26_UBERON_0000993',
#        'ali-mortazavi:068_NODJ_10F_26_UBERON_0000993',
#        'ali-mortazavi:070_NODJ_10F_26_UBERON_0000993',
#        'ali-mortazavi:072_NODJ_10F_26_UBERON_0000993',
#        'ali-mortazavi:066_NODJ_10F_26_UBERON_0000993',
#        'ali-mortazavi:038_129S1J_10F_26_UBERON_0000993',
#        'ali-mortazavi:040_129S1J_10F_26_UBERON_0000993',
#        'ali-mortazavi:044_129S1J_10F_26_UBERON_0000993',
#        'ali-mortazavi:036_129S1J_10F_26_UBERON_0000993',
#        'ali-mortazavi:088_CASTJ_10F_26_UBERON_0000993',
#        'ali-mortazavi:090_CASTJ_10F_26_UBERON_0000993',
#        'ali-mortazavi:094_CASTJ_10F_26_UBERON_0000993',
#        'ali-mortazavi:086_CASTJ_10F_26_UBERON_0000993',
#        'ali-mortazavi:019_B6J_10M_25_UBERON_0001301',
#        'ali-mortazavi:021_B6J_10M_25_UBERON_0001301',
#        'ali-mortazavi:025_B6J_10M_25_UBERON_0001301',
#        'ali-mortazavi:017_B6J_10M_25_UBERON_0001301',
#        'ali-mortazavi:069_NODJ_10M_25_UBERON_0001301',
#        'ali-mortazavi:071_NODJ_10M_25_UBERON_0001301',
#        'ali-mortazavi:073_NODJ_10M_25_UBERON_0001301',
#        'ali-mortazavi:067_NODJ_10M_25_UBERON_0001301',
#        'ali-mortazavi:041_129S1J_10M_25_UBERON_0001301',
#        'ali-mortazavi:043_129S1J_10M_25_UBERON_0001301',
#        'ali-mortazavi:045_129S1J_10M_25_UBERON_0001301',
#        'ali-mortazavi:037_129S1J_10M_25_UBERON_0001301',
#        'ali-mortazavi:089_CASTJ_10M_25_UBERON_0001301',
#        'ali-mortazavi:091_CASTJ_10M_25_UBERON_0001301',
#        'ali-mortazavi:093_CASTJ_10M_25_UBERON_0001301',
#        'ali-mortazavi:087_CASTJ_10M_25_UBERON_0001301',
#        'ali-mortazavi:017_B6J_10M_03_NTR_0000750',
#        'ali-mortazavi:018_B6J_10F_03_NTR_0000750',
#        'ali-mortazavi:019_B6J_10M_03_NTR_0000750',
#        'ali-mortazavi:016_B6J_10F_03_NTR_0000750',
#        'ali-mortazavi:021_B6J_10M_03_NTR_0000750',
#        'ali-mortazavi:024_B6J_10F_03_NTR_0000750',
#        'ali-mortazavi:025_B6J_10M_03_NTR_0000750',
#        'ali-mortazavi:020_B6J_10F_03_NTR_0000750',
#        'ali-mortazavi:029_AJ_10M_03_NTR_0000750',
#        'ali-mortazavi:028_AJ_10F_03_NTR_0000750',
#        'ali-mortazavi:031_AJ_10M_03_NTR_0000750',
#        'ali-mortazavi:026_AJ_10F_03_NTR_0000750',
#        'ali-mortazavi:033_AJ_10M_03_NTR_0000750',
#        'ali-mortazavi:032_AJ_10F_03_NTR_0000750',
#        'ali-mortazavi:035_AJ_10M_03_NTR_0000750',
#        'ali-mortazavi:030_AJ_10F_03_NTR_0000750',
#        'ali-mortazavi:037_129S1J_10M_03_NTR_0000750',
#        'ali-mortazavi:038_129S1J_10F_03_NTR_0000750',
#        'ali-mortazavi:041_129S1J_10M_03_NTR_0000750',
#        'ali-mortazavi:036_129S1J_10F_03_NTR_0000750',
#        'ali-mortazavi:043_129S1J_10M_03_NTR_0000750',
#        'ali-mortazavi:044_129S1J_10F_03_NTR_0000750',
#        'ali-mortazavi:045_129S1J_10M_03_NTR_0000750',
#        'ali-mortazavi:040_129S1J_10F_03_NTR_0000750',
#        'ali-mortazavi:057_WSBJ_10M_03_NTR_0000750',
#        'ali-mortazavi:060_WSBJ_10F_03_NTR_0000750',
#        'ali-mortazavi:059_WSBJ_10M_03_NTR_0000750',
#        'ali-mortazavi:058_WSBJ_10F_03_NTR_0000750',
#        'ali-mortazavi:061_WSBJ_10M_03_NTR_0000750',
#        'ali-mortazavi:096_WSBJ_10F_03_NTR_0000750',
#        'ali-mortazavi:063_WSBJ_10M_03_NTR_0000750',
#        'ali-mortazavi:062_WSBJ_10F_03_NTR_0000750'], dtype=object)

# %%
sample_df.dtypes
# Out:
# alias_tissue1    object
# alias_tissue2    object
# alias_tissue3    object
# alias_tissue4    object
# well_row         object
# well_col         object
# samples          object
# dtype: object
