# %%
import pandas as pd
from snakemake.io import expand
import yaml
import numpy as np
from utils import *
from sm_utils import *
from bc_utils import *

# %%
config_file = '../configs/config.yml'
with open(config_file) as f:
    config = yaml.safe_load(f)

# %%
# variables to change (again these could go in
# a future analysis spec)
# config_tsv = 'configs/test_2.tsv'
# config_tsv = 'configs/test_3.tsv'
config_tsv = '../configs/test_4.tsv'

sample_csv = '../configs/sample_metadata.csv'
kit = 'WT_mega'
chemistry = 'v2'
first_min_counts = 500

# read in config / analysis spec
df = parse_config(config_tsv)
bc_df = get_bc1_matches(kit, chemistry)
sample_df = parse_sample_df(sample_csv)

# %%
df.head()
# Out:
#                                                fastq       subpool     plate  \
# 0  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  Sublibrary_2  igvf_010
# 1  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  Sublibrary_2  igvf_010
# 2  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  Sublibrary_2  igvf_010
# 3  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  Sublibrary_2  igvf_010
# 4  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...  Sublibrary_3  igvf_010
#
#    lane  run                                 path  \
# 0  L001    1  /dfs7/samlab/seyedam/IGVF/igvf_010/
# 1  L002    1  /dfs7/samlab/seyedam/IGVF/igvf_010/
# 2  L003    1  /dfs7/samlab/seyedam/IGVF/igvf_010/
# 3  L004    1  /dfs7/samlab/seyedam/IGVF/igvf_010/
# 4  L001    1  /dfs7/samlab/seyedam/IGVF/igvf_010/
#
#                                        path2  \
# 0  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/
# 1  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/
# 2  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/
# 3  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/
# 4  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/
#
#                                             r2_fastq
# 0  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...
# 1  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...
# 2  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...
# 3  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...
# 4  /dfs7/samlab/seyedam/IGVF/igvf_010/nova1/Subli...
